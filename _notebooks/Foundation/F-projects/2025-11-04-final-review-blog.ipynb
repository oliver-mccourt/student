# %% [markdown]
# ---
# layout: background
# title: CSSE 1 Retrospective
# description: "Reflecting on my first year of computer science — from tools to JavaScript to my spooky game."
# permalink: /csse1-retrospective
# ---

# %% [markdown]
# <style>
# .progress-container {
#     display: flex;
#     gap: 30px;
#     padding: 40px 20px;
#     justify-content: center;
#     flex-wrap: wrap;
# }
#
# .progress-bubble {
#     background: linear-gradient(135deg, #0d7377 0%, #1a365d 100%);
#     border-radius: 20px;
#     padding: 30px;
#     color: white;
#     box-shadow: 0 8px 20px rgba(13, 115, 119, 0.3);
#     transition: all 0.3s ease;
#     cursor: pointer;
#     max-width: 350px;
#     min-height: 200px;
#     display: flex;
#     flex-direction: column;
#     justify-content: center;
# }
#
# .progress-bubble:hover {
#     transform: translateY(-10px) scale(1.05);
#     box-shadow: 0 15px 30px rgba(13, 115, 119, 0.5);
#     background: linear-gradient(135deg, #0e7b7f 0%, #1e3a5f 100%);
# }
#
# .bubble-title {
#     font-size: 1.4em;
#     font-weight: bold;
#     margin-bottom: 15px;
#     text-align: center;
# }
#
# .bubble-content {
#     font-size: 1em;
#     line-height: 1.6;
# }
#
# .bubble-content ul {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .bubble-content li {
#     padding: 5px 0;
#     position: relative;
#     padding-left: 20px;
# }
#
# .bubble-content li:before {
#     content: "✓";
#     position: absolute;
#     left: 0;
#     color: #4ade80;
#     font-weight: bold;
# }
#
# @media (max-width: 768px) {
#     .progress-container {
#         flex-direction: column;
#         align-items: center;
#     }
#
#     .progress-bubble {
#         max-width: 100%;
#         width: 100%;
#     }
# }
# </style>
#
#
#
# <div class="progress-container">
#     <div class="progress-bubble">
#         <div class="bubble-title">Before CSSE 1</div>
#         <div class="bubble-content">
#             Didn't know how to use terminal commands, make, or Jupyter. I was completely new to the world of computer science and felt overwhelmed by all the technical tools and concepts.
#         </div>
#     </div>
#
#     <div class="progress-bubble">
#         <div class="bubble-title">After CSSE 1</div>
#         <div class="bubble-content">
#             <ul>
#                 <li>Confident using macOS terminal</li>
#                 <li>Can set up environments and troubleshoot errors</li>
#                 <li>Comfortable cloning, committing, and pushing to GitHub</li>
#                 <li>Understand how coding connects logic and creativity</li>
#             </ul>
#         </div>
#     </div>
# </div>
