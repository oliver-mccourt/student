# %% [markdown]
# ---
# layout: background
# title: CSSE 1 Retrospective
# description: Reflecting on my first year of compsci
# permalink: /csse1-retrospective
# ---

# %% [markdown]
# <style>
# :root { color-scheme: dark; }
# html, body { background:#0b0c10; color:#e6e6e6; }
# main, .page, .post, .content, .container, .prose { background: transparent !important; }
#
# /* heading */
# .csse-retro h1 {
#   font-size: clamp(1.6rem, 2vw + 1rem, 2.2rem);
#   font-weight: 700;
#   margin: 24px 0 10px;
#   text-align: center;
# }
# .csse-retro p.lead {
#   text-align: center;
#   margin: 0 0 24px;
#   opacity: .85;
# }
#
# /* bubbles */
# .progress-container {
#   display: flex;
#   gap: 30px;
#   padding: 24px 16px 48px;
#   justify-content: center;
#   flex-wrap: wrap;
# }
#
# .progress-bubble {
#   background: linear-gradient(135deg, #0d7377 0%, #1a365d 100%);
#   border-radius: 20px;
#   padding: 30px;
#   color: #f5f7fa;
#   box-shadow: 0 8px 20px rgba(13, 115, 119, 0.3);
#   transition: transform .25s ease, box-shadow .25s ease, background .25s ease;
#   cursor: default;
#   max-width: 520px;
#   min-height: 200px;
#   display: flex;
#   flex-direction: column;
#   justify-content: center;
# }
#
# .progress-bubble:hover {
#   transform: translateY(-6px) scale(1.02);
#   box-shadow: 0 15px 30px rgba(13, 115, 119, 0.5);
#   background: linear-gradient(135deg, #0e7b7f 0%, #1e3a5f 100%);
# }
#
# .bubble-title {
#   font-size: 1.4em;
#   font-weight: 800;
#   margin-bottom: 15px;
#   text-align: center;
# }
#
# .bubble-content {
#   font-size: 1rem;
#   line-height: 1.6;
# }
#
# .bubble-content ul {
#   list-style: none;
#   padding: 0;
#   margin: 0;
# }
# .bubble-content li {
#   padding: 5px 0 5px 22px;
#   position: relative;
# }
# .bubble-content li:before {
#   content: "✓";
#   position: absolute;
#   left: 0;
#   color: #4ade80;
#   font-weight: bold;
# }
#
# @media (max-width: 768px) {
#   .progress-container { flex-direction: column; align-items: center; }
#   .progress-bubble { max-width: 100%; width: 100%; }
# }
# </style>
#
# <div class="csse-retro">
#   <h1>{{ page.title }}</h1>
#   <p class="lead">A quick before/after snapshot of my growth in CSSE 1.</p>
#
#   <div class="progress-container">
#     <div class="progress-bubble">
#       <div class="bubble-title">The Beginning of CSSE 1</div>
#       <div class="bubble-content">
#         I didn’t know how to use terminal commands, the make command, or Jupyter notebooks.
#         I was brand-new to computer science and felt overwhelmed by the tools and concepts. In the first few weeks I fell far behind and thought I wouldn't be able to create anything
#       </div>
#     </div>
#
#     <div class="progress-bubble">
#       <div class="bubble-title">The End of CSSE 1</div>
#       <div class="bubble-content">
#         <ul>
#           <li>Confident using macOS terminal</li>
#           <li>Can set up environments and troubleshoot errors</li>
#           <li>Comfortable cloning, committing, and pushing to GitHub</li>
#           <li>Understand how coding connects logic and creativity</li>
#           <li>Can troubleshoot and work through coding problems</li>
#           <li>Can use AI as a tool to help</li>
#         </ul>
#       </div>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <style>
# .spring-section {
#   background: #1a1a1a;
#   padding: 32px;
#   margin: 32px auto;
#   max-width: 1110px;
#   width: 100%;
# }
#
# .spring-header {
#   background: linear-gradient(135deg, #2a2a2a 0%, #1a1a1a 100%);
#   padding: 20px 30px;
#   text-align: center;
#   border-radius: 8px;
#   margin: 0 auto 20px;
#   color: #f0f0f0;
#   font-size: 2.2em;
#   width: 390px;
# }
#
# .blog-link {
#   display: inline-block;
#   background: #252525;
#   padding: 12px 20px;
#   border-radius: 8px;
#   text-decoration: none;
#   color: #e0e0e0;
#   margin-bottom: 24px;
#   transition: all 0.2s ease;
#   border: 1px solid #404040;
# }
#
# .blog-link:hover {
#   background: #3a3a3a;
#   color: #f0f0f0;
#   text-decoration: none;
#   border-color: #555;
# }
#
# .learned-header {
#   color: #c0c0c0;
#   margin-bottom: px;
#   font-size: 1.1em;
# }
#
# .skills-list {
#   list-style: none;
#   padding: 0;
#   margin: 0;
# }
#
# .skills-list li {
#   padding: 8px 0;
#   color: #e0e0e0;
#   line-height: 1.4;
#   position: relative;
#   padding-left: 20px;
# }
#
# .skills-list li:before {
#   content: "•";
#   position: absolute;
#   left: 0;
#   color: #c0c0c0;
# }
#
# .divider {
#   border-bottom: 1px solid #404040;
#   margin: 24px 0;
#   width: 100%;
# }
# </style>
#
# <div class="spring-section">
#   <div class="spring-header">꒰🫐꒱⋆˚࿔ SPRINT 1 𝜗𝜚˚⋆</div>
#
#   <a href="https://oliver-mccourt.github.io/student/ovm-blog/" class="blog-link">
#     Click for my first blog!!
#   </a>
#     <div class="learned-header">^^ This blog was created to showcase some big checkpoints during S1! :3</div>
#
#   <div class="divider"></div>
#
#   <div class="learned-header">I Learned to:</div>
#
#   <ul class="skills-list">
#     <li>Set up macOS for development</li>
#     <li>Use terminal commands (cd, ls, pwd, etc.)</li>
#     <li>Run make and understand Makefiles</li>
#     <li>Create, fork, and sync GitHub repositories</li>
#     <li>Collaborate with others through version control</li>
#   </ul>
# </div>

# %% [markdown]
# <style>
# .spring-section {
#   background: #1a1a1a;
#   padding: 32px;
#   margin: 32px auto;
#   max-width: 1110px;
#   width: 100%;
# }
#
# .spring-header {
#   background: linear-gradient(135deg, #2a2a2a 0%, #1a1a1a 100%);
#   padding: 20px 30px;
#   text-align: center;
#   border-radius: 8px;
#   margin: 0 auto 20px;
#   color: #f0f0f0;
#   font-size: 2.2em;
#   width: 390px;
# }
#
# .blog-link {
#   display: inline-block;
#   background: #252525;
#   padding: 12px 20px;
#   border-radius: 8px;
#   text-decoration: none;
#   color: #e0e0e0;
#   margin-bottom: 24px;
#   transition: all 0.2s ease;
#   border: 1px solid #404040;
# }
#
# .blog-link:hover {
#   background: #3a3a3a;
#   color: #f0f0f0;
#   text-decoration: none;
#   border-color: #555;
# }
#
# .learned-header {
#   color: #c0c0c0;
#   margin-bottom: 16px;
#   font-size: 1.1em;
# }
#
# .skills-list {
#   list-style: none;
#   padding: 0;
#   margin: 0;
# }
#
# .skills-list li {
#   padding: 8px 0;
#   color: #e0e0e0;
#   line-height: 1.4;
#   position: relative;
#   padding-left: 20px;
# }
#
# .skills-list li:before {
#   content: "•";
#   position: absolute;
#   left: 0;
#   color: #c0c0c0;
# }
#
# .divider {
#   border-bottom: 1px solid #404040;
#   margin: 24px 0;
#   width: 100%;
# }
# </style>
#
# <div class="spring-section">
#   <div class="spring-header">꒰🌱꒱ ‘ . SPRINT 2 —“⟡</div>
#
#     <div class="learned-header">^^ Sprint 2 was about learning and teaching the basics of Javascript</div>
#
# <a href="https://precia-verma.github.io/Group-projects/front-page/" class="blog-link">
#     Click for a highlight of the beginning of S2
#     </a>
#
# <a href="https://pages.opencodingsociety.com/javascript/boolean-blog" class="blog-link">
#     Boolean Blog
#     </a>
#
# <a href="https://pages.opencodingsociety.com/javascript/array/lesson" class="blog-link">
#     Arrays Blog
#     </a>
#
#   <div class="divider"></div>
#
#   <div class="learned-header">I Focused On:</div>
#
#   <ul class="skills-list">
#     <li>Javascript basics</li>
#     <li>Learning about variables, loops, functions, conditionals, arrays, booleans, classes, etc</li>
#     <li>Creating and customizing blogs</li>
#     <li>Teaching peers</li>
#     <li>Learning from peers</li>
#   </ul>
#
#   <div class="divider"></div>
#
#   <div class="learned-header">However, during S2, our team faced many issues:</div>
#
#   <ul class="skills-list">
#     <li>Theme bugs/errors right before presentation!!</li>
#     <li>Creating functional and effective homework to help my peers learn</li>
#     <li>Teaching peers</li>
#     <li>Learning from peers</li>
#   </ul>
# </div>

# %% [markdown]
# <style>
# .spring-section {
#   background: #1a1a1a;
#   padding: 32px;
#   margin: 32px auto;
#   max-width: 1110px;
#   width: 100%;
# }
#
# .spring-header {
#   background: linear-gradient(135deg, #2a2a2a 0%, #1a1a1a 100%);
#   padding: 20px 30px;
#   text-align: center;
#   border-radius: 8px;
#   margin: 0 auto 20px;
#   color: #f0f0f0;
#   font-size: 2.2em;
#   width: 390px;
# }
#
# .blog-link {
#   display: inline-block;
#   background: #252525;
#   padding: 12px 20px;
#   border-radius: 8px;
#   text-decoration: none;
#   color: #e0e0e0;
#   margin-bottom: 24px;
#   transition: all 0.2s ease;
#   border: 1px solid #404040;
# }
#
# .blog-link:hover {
#   background: #3a3a3a;
#   color: #f0f0f0;
#   text-decoration: none;
#   border-color: #555;
# }
#
# .learned-header {
#   color: #c0c0c0;
#   margin-bottom: 16px;
#   font-size: 1.1em;
# }
#
# .skills-list {
#   list-style: none;
#   padding: 0;
#   margin: 0;
# }
#
# .skills-list li {
#   padding: 8px 0;
#   color: #e0e0e0;
#   line-height: 1.4;
#   position: relative;
#   padding-left: 20px;
# }
#
# .skills-list li:before {
#   content: "•";
#   position: absolute;
#   left: 0;
#   color: #c0c0c0;
# }
#
# .divider {
#   border-bottom: 1px solid #404040;
#   margin: 24px 0;
#   width: 100%;
# }
# </style>
#
# <div class="spring-section">
#   <div class="spring-header">꒰🌀꒱﹒⌗┊ SPRINT 3 ‧₊˚</div>
#
#     <div class="learned-header">^^ Sprint 3 combined all elements from S1 and S2 to create our biggest project yet...</div>
#
#   <div class="learned-header">SPOOKY MANSION GAME!!!!!!!</div>
#   ⎛|㇏₍^. ̞.^₎ノ|⎞
#
#   <a href="https://pages.opencodingsociety.com/gamify/mansionGame" class="blog-link">
#     Mansion Game! (ours on level 2)
#     </a>
#
#
#   <div class="divider"></div>
#
#   <div class="learned-header">We, The Coders, with help from our peers, were able to create Level 2 of the Mansion Game: The Gravestone Memory Game</div>
#
#   <ul class="skills-list">
#     <li>A simon-says style memory game</li>
#     <li>Players must remember the sequence in which each gravestone lights up</li>
#     <li>Includes interactive features (buttons, canvas background, visual feedback)</li>
#   </ul>
#
#   <div class="divider"></div>
#
#   <div class="learned-header">During the making of this game, we used fundemental concepts from S1 and S2 to help create a working game (concepts include but are not limited to):</div>
#
#   <ul class="skills-list">
#     <li>Variables --> const/let</li>
#     <li>Arrays --> gravestone objects</li>
#     <li>Loops --> for loop in rounds and in sequence</li>
#     <li>Functions --> resizing canvas</li>
#     <li>Classes --> hitbox, glowing effect,</li>
#   </ul>
#
# </div>

# %% [markdown]
# <style>
# .museum-container {
#   display: flex;
#   justify-content: center;
#   padding: 24px 16px 48px;
# }
#
# .museum-bubble {
#   background: linear-gradient(135deg, #0d7377 0%, #1a365d 100%);
#   border-radius: 20px;
#   padding: 20px 30px;
#   color: #f5f7fa;
#   box-shadow: 0 8px 20px rgba(13, 115, 119, 0.3);
#   transition: transform .25s ease, box-shadow .25s ease, background .25s ease;
#   cursor: default;
#   max-width: 1110px;
#   width: 100%;
#   min-height: 80px;
#   display: flex;
#   flex-direction: column;
#   justify-content: center;
# }
#
# .museum-bubble:hover {
#   transform: translateY(-6px) scale(1.02);
#   box-shadow: 0 15px 30px rgba(13, 115, 119, 0.5);
#   background: linear-gradient(135deg, #0e7b7f 0%, #1e3a5f 100%);
# }
#
# .museum-bubble-title {
#   font-size: 1.8em;
#   font-weight: 800;
#   margin-bottom: 15px;
#   text-align: center;
# }
# </style>
#
# <div class="museum-container">
#   <div class="museum-bubble">
#     <div class="museum-bubble-title">✦•┈๑⋅⋯Night At The Museum⋯⋅๑┈•✦</div>
#   </div>
# </div>

# %% [markdown]
# <style>
# .spring-section {
#   background: linear-gradient(135deg, #2a2a2aff 0%, #0a0a0a 100%);
#   border-radius: 12px;
#   padding: 32px;
#   margin: 32px auto;
#   max-width: 1110px;
#   width: 100%;
# }
#
# .spring-header {
#   background: linear-gradient(135deg, #2a2a2a 0%, #1a1a1a 100%);
#   padding: 20px 30px;
#   text-align: center;
#   border-radius: 8px;
#   margin: 0 auto 20px;
#   color: #f0f0f0;
#   font-size: 2.2em;
#   width: 390px;
# }
#
# .blog-link {
#   display: inline-block;
#   background: #252525;
#   padding: 12px 20px;
#   border-radius: 8px;
#   text-decoration: none;
#   color: #e0e0e0;
#   margin-bottom: 24px;
#   transition: all 0.2s ease;
#   border: 1px solid #404040;
# }
#
# .blog-link:hover {
#   background: #3a3a3a;
#   color: #f0f0f0;
#   text-decoration: none;
#   border-color: #555;
# }
#
# .learned-header {
#   color: #c0c0c0;
#   margin-bottom: 16px;
#   font-size: 1.1em;
# }
#
# .skills-list {
#   list-style: none;
#   padding: 0;
#   margin: 0;
# }
#
# .skills-list li {
#   padding: 8px 0;
#   color: #e0e0e0;
#   line-height: 1.4;
#   position: relative;
#   padding-left: 20px;
# }
#
# .skills-list li:before {
#   content: "•";
#   position: absolute;
#   left: 0;
#   color: #c0c0c0;
# }
#
# .divider {
#   border-bottom: 1px solid #404040;
#   margin: 24px 0;
#   width: 100%;
# }
# </style>
#
# <div class="spring-section">
#
# <div class="learned-header">N@TM was a great experience! Our group was able to finally showcase our creation with the rest of the class. The process--while heavily unorganized--allowed us to present our working game as a final project from CSSE 1, showing our progress through this trimester. We had the parents come around us and have them learn and play the game as we then guided them level through level. Many of the parents enjoyed seeing our work paying off into being able to code a functioning game! I had a few parents comment about our creativity and execution being very impressive.</div>
# </div>

# %% [markdown]
# <style>
# .museum-container {
#   display: flex;
#   justify-content: center;
#   padding: 24px 16px 48px;
# }
#
# .museum-bubble {
#   background: linear-gradient(135deg, #0d7377 0%, #1a365d 100%);
#   border-radius: 20px;
#   padding: 20px 30px;
#   color: #f5f7fa;
#   box-shadow: 0 8px 20px rgba(13, 115, 119, 0.3);
#   transition: transform .25s ease, box-shadow .25s ease, background .25s ease;
#   cursor: default;
#   max-width: 1110px;
#   width: 100%;
#   min-height: 80px;
#   display: flex;
#   flex-direction: column;
#   justify-content: center;
# }
#
# .museum-bubble:hover {
#   transform: translateY(-6px) scale(1.02);
#   box-shadow: 0 15px 30px rgba(13, 115, 119, 0.5);
#   background: linear-gradient(135deg, #0e7b7f 0%, #1e3a5f 100%);
# }
#
# .museum-bubble-title {
#   font-size: 1.8em;
#   font-weight: 800;
#   margin-bottom: 15px;
#   text-align: center;
# }
# </style>
#
# <div class="museum-container">
#   <div class="museum-bubble">
#     <div class="museum-bubble-title">✦•┈๑⋅⋯Future Goals!!⋯⋅๑┈•✦</div>
#   </div>
# </div>

# %% [markdown]
# <style>
# .spring-section {
#   background: linear-gradient(135deg, #2a2a2aff 0%, #0a0a0a 100%);
#   border-radius: 12px;
#   padding: 32px;
#   margin: 32px auto;
#   max-width: 1110px;
#   width: 100%;
# }
#
# .spring-header {
#   background: linear-gradient(135deg, #2a2a2a 0%, #1a1a1a 100%);
#   padding: 20px 30px;
#   text-align: center;
#   border-radius: 8px;
#   margin: 0 auto 20px;
#   color: #f0f0f0;
#   font-size: 2.2em;
#   width: 390px;
# }
#
# .blog-link {
#   display: inline-block;
#   background: #252525;
#   padding: 12px 20px;
#   border-radius: 8px;
#   text-decoration: none;
#   color: #e0e0e0;
#   margin-bottom: 24px;
#   transition: all 0.2s ease;
#   border: 1px solid #404040;
# }
#
# .blog-link:hover {
#   background: #3a3a3a;
#   color: #f0f0f0;
#   text-decoration: none;
#   border-color: #555;
# }
#
# .learned-header {
#   color: #c0c0c0;
#   margin-bottom: 16px;
#   font-size: 1.1em;
# }
#
# .skills-list {
#   list-style: none;
#   padding: 0;
#   margin: 0;
# }
#
# .skills-list li {
#   padding: 8px 0;
#   color: #e0e0e0;
#   line-height: 1.4;
#   position: relative;
#   padding-left: 20px;
# }
#
# .skills-list li:before {
#   content: "•";
#   position: absolute;
#   left: 0;
#   color: #c0c0c0;
# }
#
# .divider {
#   border-bottom: 1px solid #404040;
#   margin: 24px 0;
#   width: 100%;
# }
# </style>
#
# <div class="spring-section">
#
# <div class="learned-header">In the future, if I had more time I'd like to:</div>
#
#  <div class="divider"></div>
#
#   <ul class="skills-list">
#     <li>Implement sprite/character</li>
#     <li>E key for sprite to press gravestones</li>
#     <li>Add in musical notes for the gravestones</li>
#     <li>Create a smoother looking game</li>
#   </ul>
#
# </div>

# %% [markdown]
# <style>
# .spring-section {
#   background: #1a1a1a;
#   padding: 32px;
#   margin: 32px auto;
#   max-width: 1110px;
#   width: 100%;
# }
#
# .spring-header {
#   background: linear-gradient(135deg, #2a2a2a 0%, #1a1a1a 100%);
#   padding: 20px 30px;
#   text-align: center;
#   border-radius: 8px;
#   margin: 0 auto 20px;
#   color: #f0f0f0;
#   font-size: 2.2em;
#   width: 390px;
# }
#
# .blog-link {
#   display: inline-block;
#   background: #252525;
#   padding: 12px 20px;
#   border-radius: 8px;
#   text-decoration: none;
#   color: #e0e0e0;
#   margin-bottom: 24px;
#   transition: all 0.2s ease;
#   border: 1px solid #404040;
# }
#
# .blog-link:hover {
#   background: #3a3a3a;
#   color: #f0f0f0;
#   text-decoration: none;
#   border-color: #555;
# }
#
# .learned-header {
#   color: #c0c0c0;
#   margin-bottom: 16px;
#   font-size: 1.1em;
# }
#
# .skills-list {
#   list-style: none;
#   padding: 0;
#   margin: 0;
# }
#
# .skills-list li {
#   padding: 8px 0;
#   color: #e0e0e0;
#   line-height: 1.4;
#   position: relative;
#   padding-left: 20px;
# }
#
# .skills-list li:before {
#   content: "•";
#   position: absolute;
#   left: 0;
#   color: #c0c0c0;
# }
#
# .divider {
#   border-bottom: 1px solid #404040;
#   margin: 24px 0;
#   width: 100%;
# }
# </style>
#
# <div class="spring-section">
#   <div class="spring-header">One Cool Thing!</div>
#
# <div class="learned-header">At the end of the day, I learned that the coolest thing was the collaborative aspect of coding. It was amazing to see people work together to teach core concepts, and then create a working game together as a class.</div>
#
# </div>

# %% [markdown]
# <style>
# .museum-container {
#   display: flex;
#   justify-content: center;
#   padding: 24px 16px 48px;
# }
#
# .museum-bubble {
#   background: linear-gradient(135deg, #0d7377 0%, #1a365d 100%);
#   border-radius: 20px;
#   padding: 20px 30px;
#   color: #f5f7fa;
#   box-shadow: 0 8px 20px rgba(13, 115, 119, 0.3);
#   transition: transform .25s ease, box-shadow .25s ease, background .25s ease;
#   cursor: default;
#   max-width: 1110px;
#   width: 100%;
#   min-height: 80px;
#   display: flex;
#   flex-direction: column;
#   justify-content: center;
# }
#
# .museum-bubble:hover {
#   transform: translateY(-6px) scale(1.02);
#   box-shadow: 0 15px 30px rgba(13, 115, 119, 0.5);
#   background: linear-gradient(135deg, #0e7b7f 0%, #1e3a5f 100%);
# }
#
# .museum-bubble-title {
#   font-size: 1.8em;
#   font-weight: 800;
#   margin-bottom: 15px;
#   text-align: center;
# }
# </style>
#
# <div class="museum-container">
#   <div class="museum-bubble">
#     <div class="museum-bubble-title">✦•┈๑⋅⋯What I'd Like to Learn Next⋯⋅๑┈•✦</div>
#   </div>
# </div>

# %% [markdown]
# <style>
# .spring-section {
#   background: linear-gradient(135deg, #2a2a2aff 0%, #0a0a0a 100%);
#   border-radius: 12px;
#   padding: 32px;
#   margin: 32px auto;
#   max-width: 1110px;
#   width: 100%;
# }
#
# .spring-header {
#   background: linear-gradient(135deg, #2a2a2a 0%, #1a1a1a 100%);
#   padding: 20px 30px;
#   text-align: center;
#   border-radius: 8px;
#   margin: 0 auto 20px;
#   color: #f0f0f0;
#   font-size: 2.2em;
#   width: 390px;
# }
#
# .blog-link {
#   display: inline-block;
#   background: #252525;
#   padding: 12px 20px;
#   border-radius: 8px;
#   text-decoration: none;
#   color: #e0e0e0;
#   margin-bottom: 24px;
#   transition: all 0.2s ease;
#   border: 1px solid #404040;
# }
#
# .blog-link:hover {
#   background: #3a3a3a;
#   color: #f0f0f0;
#   text-decoration: none;
#   border-color: #555;
# }
#
# .learned-header {
#   color: #c0c0c0;
#   margin-bottom: 16px;
#   font-size: 1.1em;
# }
#
# .skills-list {
#   list-style: none;
#   padding: 0;
#   margin: 0;
# }
#
# .skills-list li {
#   padding: 8px 0;
#   color: #e0e0e0;
#   line-height: 1.4;
#   position: relative;
#   padding-left: 20px;
# }
#
# .skills-list li:before {
#   content: "•";
#   position: absolute;
#   left: 0;
#   color: #c0c0c0;
# }
#
# .divider {
#   border-bottom: 1px solid #404040;
#   margin: 24px 0;
#   width: 100%;
# }
# </style>
#
# <div class="spring-section">
#
# <div class="learned-header">In the future, I'd like to learn about</div>
#
#  <div class="divider"></div>
#
#   <ul class="skills-list">
#     <li>mobile game development</li>
#     <li>more complex games that include cutscenes, fights, and things beyond WASD keys</li>
#   </ul>
#
# </div>

# %% [markdown]
# <style>
# .analytics-container {
#   display: flex;
#   justify-content: center;
#   padding: 24px 16px 48px;
# }
#
# .analytics-bubble {
#   background: linear-gradient(135deg, #0d7377 0%, #1a365d 100%);
#   border-radius: 20px;
#   padding: 20px 30px;
#   color: #f5f7fa;
#   box-shadow: 0 8px 20px rgba(13, 115, 119, 0.3);
#   transition: transform .25s ease, box-shadow .25s ease, background .25s ease;
#   cursor: default;
#   max-width: 1110px;
#   width: 100%;
#   min-height: 80px;
#   display: flex;
#   flex-direction: column;
#   justify-content: center;
# }
#
# .analytics-bubble:hover {
#   transform: translateY(-6px) scale(1.02);
#   box-shadow: 0 15px 30px rgba(13, 115, 119, 0.5);
#   background: linear-gradient(135deg, #0e7b7f 0%, #1e3a5f 100%);
# }
#
# .analytics-bubble-title {
#   font-size: 1.8em;
#   font-weight: 800;
#   margin-bottom: 15px;
#   text-align: center;
# }
# </style>
#
# <div class="analytics-container">
#   <div class="analytics-bubble">
#     <div class="analytics-bubble-title">✦•┈๑⋅⋯Analytics Review⋯⋅๑┈•✦</div>
#   </div>
# </div>

# %% [markdown]
# <style>
# .analytics-section {
#   background: linear-gradient(135deg, #1a1a1a 0%, #0a0a0a 100%);
#   border-radius: 12px;
#   padding: 32px;
#   margin: 32px auto;
#   max-width: 1110px;
#   width: 100%;
# }
#
# .metrics-grid {
#   display: grid;
#   grid-template-columns: repeat(auto-fit, minmax(280px, 1fr));
#   gap: 24px;
#   margin: 24px 0;
# }
#
# .metric-card {
#   background: linear-gradient(135deg, #2a2a2a 10%, #1a1a1a 90%);
#   border-radius: 12px;
#   padding: 24px;
#   border: 1px solid #404040;
#   transition: all 0.3s ease;
# }
#
# .metric-card:hover {
#   border-color: #0d7377;
#   box-shadow: 0 4px 16px rgba(13, 115, 119, 0.2);
#   transform: translateY(-2px);
# }
#
# .metric-number {
#   font-size: 2.4em;
#   font-weight: 800;
#   color: #4ade80;
#   margin-bottom: 8px;
#   display: block;
# }
#
# .metric-label {
#   color: #c0c0c0;
#   font-size: 1.1em;
#   margin-bottom: 12px;
# }
#
# .metric-description {
#   color: #e0e0e0;
#   font-size: 0.9em;
#   line-height: 1.4;
# }
#
# .analytics-header {
#   color: #c0c0c0;
#   margin-bottom: 16px;
#   font-size: 1.1em;
# }
#
# .progress-bar {
#   background: #2a2a2a;
#   height: 8px;
#   border-radius: 4px;
#   margin: 12px 0;
#   overflow: hidden;
# }
#
# .progress-fill {
#   height: 100%;
#   background: linear-gradient(90deg, #0d7377, #4ade80);
#   transition: width 0.5s ease;
# }
#
# .analytics-insights {
#   background: #252525;
#   border-left: 4px solid #0d7377;
#   padding: 20px;
#   margin: 24px 0;
#   border-radius: 0 8px 8px 0;
# }
#
# .insight-title {
#   color: #4ade80;
#   font-weight: 700;
#   margin-bottom: 8px;
# }
#
# .divider {
#   border-bottom: 1px solid #404040;
#   margin: 24px 0;
#   width: 100%;
# }
# </style>
#
# <div class="analytics-section">
#
#   <div class="metrics-grid">
#     <div class="metric-card">
#       <span class="metric-number">12</span>
#       <div class="metric-label">Weeks of Learning</div>
#       <div class="metric-description">From complete beginner to confident coder</div>
#       <div class="progress-bar">
#         <div class="progress-fill" style="width: 100%;"></div>
#       </div>
#     </div>
#
#     <div class="metric-card">
#       <span class="metric-number">3</span>
#       <div class="metric-label">Major Sprints</div>
#       <div class="metric-description">Each building foundational skills</div>
#       <div class="progress-bar">
#         <div class="progress-fill" style="width: 100%;"></div>
#       </div>
#     </div>
#
#     <div class="metric-card">
#       <span class="metric-number">200+</span>
#       <div class="metric-label">GitHub Commits</div>
#       <div class="metric-description">Tracking progress through version control</div>
#       <div class="progress-bar">
#         <div class="progress-fill" style="width: 85%;"></div>
#       </div>
#     </div>
#
#     <div class="metric-card">
#       <span class="metric-number">50+</span>
#       <div class="metric-label">Terminal Commands</div>
#       <div class="metric-description">From zero to countless</div>
#       <div class="progress-bar">
#         <div class="progress-fill" style="width: 90%;"></div>
#       </div>
#     </div>
#
#     <div class="metric-card">
#       <span class="metric-number">8</span>
#       <div class="metric-label">Blog Posts Created</div>
#       <div class="metric-description">Teaching and documenting learning</div>
#       <div class="progress-bar">
#         <div class="progress-fill" style="width: 75%;"></div>
#       </div>
#     </div>
#
#     <div class="metric-card">
#       <span class="metric-number">1</span>
#       <div class="metric-label">Complete Game Built</div>
#       <div class="metric-description">Gravestone Memory Game in Sprint 3</div>
#       <div class="progress-bar">
#         <div class="progress-fill" style="width: 100%;"></div>
#       </div>
#     </div>
#   </div>
#
#   <div class="divider"></div>
#
#   <div class="analytics-header">GitHub Commit Visualizations:</div>
#
#   <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(400px, 1fr)); gap: 24px; margin: 24px 0;">
#     <div style="background: #252525; padding: 20px; border-radius: 12px; border: 1px solid #404040;">
#       <div style="color: #c0c0c0; margin-bottom: 12px; font-weight: 600; text-align: center;">Personal Repository Commits</div>
#       <img src="{{ site.baseurl }}/images/commits-of-om.png" alt="Personal repository commit history" style="width: 100%; height: auto; border-radius: 8px; border: 1px solid #404040;">
#     </div>
#
#     <div style="background: #252525; padding: 20px; border-radius: 12px; border: 1px solid #404040;">
#       <div style="color: #c0c0c0; margin-bottom: 12px; font-weight: 600; text-align: center;">Group Project Commits</div>
#       <img src="{{ site.baseurl }}/images/commits-of-pv.png" alt="Group project commit history" style="width: 100%; height: auto; border-radius: 8px; border: 1px solid #404040;">
#     </div>
#   </div>
#
#   <div class="analytics-insights">
#     <div class="insight-title">Commit Patterns Insights:</div>
#     <div style="color: #e0e0e0; line-height: 1.6;">
#       • <strong>Consistency:</strong> Regular commits throughout the trimester showing sustained effort<br>
#       • <strong>Collaboration:</strong> Active participation in group projects with meaningful contributions<br>
#       • <strong>Growth:</strong> Commit frequency and complexity increased as confidence grew<br>
#       • <strong>Documentation:</strong> Commit messages improved over time, showing better development practices
#     </div>
#   </div>
#
#   <div>
