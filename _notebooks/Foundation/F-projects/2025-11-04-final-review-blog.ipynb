# %% [markdown]
# ---
# layout: background
# title: CSSE 1 Retrospective
# description: Reflecting on my first year of compsci
# permalink: /csse1-retrospective
# ---

# %% [markdown]
# ---
# layout: student          # use the same dark layout as /student
# title: CSSE 1 Retrospective
# permalink: /student/csse1-retrospective
# ---
#
# <style>
# /* --- force dark background & prevent white layouts from bleeding in --- */
# :root { color-scheme: dark; }
# html, body { background:#0b0c10; color:#e6e6e6; }
# main, .page, .post, .content, .container, .prose { background: transparent !important; }
#
# /* --- page heading --- */
# .csse-retro h1 {
#   font-size: clamp(1.6rem, 2vw + 1rem, 2.2rem);
#   font-weight: 700;
#   margin: 24px 0 10px;
#   text-align: center;
# }
# .csse-retro p.lead {
#   text-align: center;
#   margin: 0 0 24px;
#   opacity: .85;
# }
#
# /* --- bubbles --- */
# .progress-container {
#   display: flex;
#   gap: 30px;
#   padding: 24px 16px 48px;
#   justify-content: center;
#   flex-wrap: wrap;
# }
#
# .progress-bubble {
#   background: linear-gradient(135deg, #0d7377 0%, #1a365d 100%);
#   border-radius: 20px;
#   padding: 30px;
#   color: #f5f7fa;
#   box-shadow: 0 8px 20px rgba(13, 115, 119, 0.3);
#   transition: transform .25s ease, box-shadow .25s ease, background .25s ease;
#   cursor: default;
#   max-width: 520px;
#   min-height: 200px;
#   display: flex;
#   flex-direction: column;
#   justify-content: center;
# }
#
# .progress-bubble:hover {
#   transform: translateY(-6px) scale(1.02);
#   box-shadow: 0 15px 30px rgba(13, 115, 119, 0.5);
#   background: linear-gradient(135deg, #0e7b7f 0%, #1e3a5f 100%);
# }
#
# .bubble-title {
#   font-size: 1.4em;
#   font-weight: 800;
#   margin-bottom: 15px;
#   text-align: center;
# }
#
# .bubble-content {
#   font-size: 1rem;
#   line-height: 1.6;
# }
#
# .bubble-content ul {
#   list-style: none;
#   padding: 0;
#   margin: 0;
# }
# .bubble-content li {
#   padding: 5px 0 5px 22px;
#   position: relative;
# }
# .bubble-content li:before {
#   content: "✓";
#   position: absolute;
#   left: 0;
#   color: #4ade80;
#   font-weight: bold;
# }
#
# @media (max-width: 768px) {
#   .progress-container { flex-direction: column; align-items: center; }
#   .progress-bubble { max-width: 100%; width: 100%; }
# }
# </style>
#
# <div class="csse-retro">
#   <h1>{{ page.title }}</h1>
#   <p class="lead">A quick before/after snapshot of my growth in CSSE 1.</p>
#
#   <div class="progress-container">
#     <div class="progress-bubble">
#       <div class="bubble-title">Before CSSE 1</div>
#       <div class="bubble-content">
#         I didn’t know how to use terminal commands, <code>make</code>, or Jupyter.
#         I was brand-new to computer science and felt overwhelmed by the tools and concepts.
#       </div>
#     </div>
#
#     <div class="progress-bubble">
#       <div class="bubble-title">After CSSE 1</div>
#       <div class="bubble-content">
#         <ul>
#           <li>Confident using macOS terminal</li>
#           <li>Can set up environments and troubleshoot errors</li>
#           <li>Comfortable cloning, committing, and pushing to GitHub</li>
#           <li>Understand how coding connects logic and creativity</li>
#         </ul>
#       </div>
#     </div>
#   </div>
# </div>
